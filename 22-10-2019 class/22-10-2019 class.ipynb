# %%
# line plot
import matplotlib.pyplot as p
x=[1,2,3,4,5]
y=[4,5,6,7,8]
p.plot(x,y)
p.show()

# %%
# by using range display lineplot
import matplotlib.pyplot as p_l
x=list(range(1,10,2))
y=list(range(20,30,2))
p_l.plot(x,y,'go')
p_l.show()

# %%
for i in range(10,20,2):
    print(i)
# Out:
# 10
# 12
# 14
# 16
# 18

# %%
# x=(1,10,2)
#y=(20,30,2)
for i in range(1,10,2):
    x.append(i)
x
# Out:
# [1, 3, 5, 7, 9, 1, 3, 5, 7, 9]

# %%
l=[i for i in range(1,10,2)]
l
# Out:
# [1, 3, 5, 7, 9]

# %%
# lineplot by using list comphrension for 1-10 inters
x=[i for i in range(1,10,1)]
y=[i**2 for i in range(1,10,1)]
p.plot(x,y,'rv')
p.grid()

# %% [markdown]
# # label names and title for a graph
# #lib.xlabel('x-axis')
# #lib.title('sqrt of 1-10')

# %% [markdown]
# ### lib.title('sqrt of 1-10') ###

# %%
import matplotlib.pyplot as h
x=[2,4]
y=[2,0]
h.plot(x,y)
h.xlabel('x-Data')
h.ylabel('y-Axis')
h.title('line plot')
h.grid()
h.show()

# %%
# bargraph
import matplotlib.pyplot as pl
x=list(range(1,10,3))
print(x)
y=[3,5,8]
pl.bar(x,y)
# Out:
# [1, 4, 7]
# <BarContainer object of 3 artists>

# %%
# scatter
#histogram

# %%
help(pl.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x, bins=None, range=None, density=None, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, normed=None, *, data=None, **kwargs)
#     Plot a histogram.
#
#     Compute and draw the histogram of *x*.  The return value is a tuple
#     (*n*, *bins*, *patches*) or ([*n0*, *n1*, ...], *bins*, [*patches0*,
#     *patches1*,...]) if the input contains multiple data.  See the
#     documentation of the *weights* parameter to draw a histogram of
#     already-binned data.
#
#     Multiple data can be provided via *x* as a list of datasets
#     of potentially different length ([*x0*, *x1*, ...]), or as
#     a 2-D ndarray in which each column is a dataset.  Note that
#     the ndarray form is transposed relative to the list form.
#
#     Masked arrays are not supported at present.
#
#     Parameters
#     ----------
# ...

# %%
# scatter
x=list(range(1,10,3))
print(x)
y=[3,5,8]
pl.bar(x,y)
p.scatter(x,y)
# Out:
# [1, 4, 7]

# %%
# histogram plot
x=list(range(1,11,2))
p.hist(x)
p.grid()

# %%
# draw a plot for time and distance
distance=2

# %%
## print x= time,y=distance along with labels 
x=[time for time in range(10,21,2)]
y=[distance*2 for distance in range(1,12,2)]
p.plot(x,y,'rv')
#p.grid()
p.show()

# %% [markdown]
# # getting images by using matplotlib

# %%
import matplotlib.pyplot as pl
import matplotlib.image as m
image=m.imread('alluarjun.jpg')
pl.imshow(image)

# %%
# applying psudo color to an image
import matplotlib.pyplot as pl
import matplotlib.image as m
x=m.imread('alluarjun.jpg')
c=x[:,:, 0]# apply psudo color
pl.imshow(c,cmap='hot')
pl.colorbar()

# %% [markdown]
# ## matplotlib ticks
#      ticks is value with in a coordinates

# %%
import matplotlib.pyplot as p
y=[5,51,5,2,9]
print(x)
x=[9,78,3,71,8]
print(y)
pl.plot(x,y)
pl.title("A graph a withexample to ticks")
p.xlabel("natural numbers")
p.xlabel("value with ++5 up to 50")
# Out:
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
# [5, 51, 5, 2, 9]
# Text(0.5, 0, 'value with ++5 up to 50')

# %%
import matplotlib.pyplot as pl
import numpy as np
pl.xticks(np.arrange(1,20,1,))
pl.yticks(np.arrange(5,51,5))
pl.plot(x,y)
print(x)
print(y)
pl.title("matplot-ticks")
pl.xlabel('10 natural  numbers')
pl.ylabel('5-50 values with 5+')
pl.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-51e172e66aa0> in <module>
#       1 import matplotlib.pyplot as pl
#       2 import numpy as np
# ----> 3 pl.xticks(np.arrange(1,20,1,))
#       4 pl.yticks(np.arrange(5,51,5))
#       5 pl.plot(x,y)
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %% [markdown]
# # representing a sine wave
# A=sine(wt)
# A=Amplitudw
# w=frequency
# t=time

# %%
import numpy as np
import matplotlib.pyplot as pl
Time=np.arrange(1,10,0.1)
Amplitude=np.sin(t)
pl.plot(Time,Amplitude)
pl.title("sine wave A=sin(wt)")
xlabel('time')
ylabel('amplitude')
pl.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-e1e179841a9e> in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as pl
# ----> 3 Time=np.arrange(1,10,0.1)
#       4 Amplitude=np.sin(t)
#       5 pl.plot(Time,Amplitude)
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
import pandas as pd
df=pd.read_csv("income.csv")
df
# Out:
#                 State   2005   2006   2007   2008   2009   2010   2011   2012  \
# 04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590  43464
# 04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431  63648
# 04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621  47044
# 04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302  39018
# 04000US06  California  51755  55319  55734  57014  56134  54283  53367  57020
#
#             2013
# 04000US01  41381
# 04000US02  61137
# 04000US04  50602
# 04000US05  39919
# 04000US06  57528

# %%
import matplotlib.pyplot as l
years=df.columns[2::]
#years
Alasaka_income =df.iloc[1,2:]
pl.plot(years,Alasaka_income)
pl.title("Income of Alaska from 2005-2013")
pl.xlabel("years")
pl.ylabel("Income of Alaska")
pl.savefig("")
p.show()

# %% [markdown]
# # plot for all states income from 2005-2013
# ## x-axis=years
# ## y-axis=all states

# %%
## print the all states income from 2008-2013
import matplotlib.pyplot as l
years=df.columns[2::]
#years
Alasaka_income =df.iloc[1,2:]
pl.plot(years,Alasaka_income)
pl.title("Income of all states from 2005-2013")
pl.xlabel("years")
pl.ylabel("states")
p.show()

# %%
import matplotlib.pyplot as pl
import pandas as pd
year=df.columns[-5::]
allstate_income=df.iloc[0:,2:]
p.plot("years")
p.ylabel("states")
p.save
